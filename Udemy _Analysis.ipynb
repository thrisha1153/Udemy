# %%
pip install plotly nbformat
# Out:
# Requirement already satisfied: plotly in c:\users\thris\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (5.22.0)
# Requirement already satisfied: nbformat in c:\users\thris\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (5.10.4)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\thris\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from plotly) (8.4.1)
# Requirement already satisfied: packaging in c:\users\thris\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from plotly) (23.1)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\thris\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from nbformat) (2.20.0)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\thris\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from nbformat) (4.22.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\thris\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from nbformat) (5.3.0)
# Requirement already satisfied: traitlets>=5.1 in c:\users\thris\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from nbformat) (5.9.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\thris\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jsonschema>=2.6->nbformat) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\thris\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jsonschema>=2.6->nbformat) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\thris\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jsonschema>=2.6->nbformat) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\thris\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jsonschema>=2.6->nbformat) (0.18.1)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\thris\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (3.5.0)
# Requirement already satisfied: pywin32>=300 in c:\users\thris\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (306)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 24.0
# [notice] To update, run: C:\Users\thris\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# DESIGN COURSE

# %%
d1=pd.read_csv("C:\\Users\\thris\\Downloads\\Design Courses.csv")
d1.head(2)
# Out:
#    course_id                                       course_title  price
# 0     348116  Photoshop In-Depth: Master all of Photoshop's ...      0  \
# 1      17349  Figure Drawing From Life Using The Reilly Tech...      0
#
#   Free/Paid  num_subscribers  num_reviews  num_lectures           level
# 0      Free            53851         1779            45      All Levels  \
# 1      Free            47811         1041            22  Beginner Level
#
#    Rating  content_duration  published_  Year  Month         subject  Revenue
# 0    0.69               4.5  30-11-2014  2014     11  Graphic Design        0
# 1    0.11               2.5  09-05-2012  2012      5  Graphic Design        0

# %%
d1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 602 entries, 0 to 601
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   course_id         602 non-null    int64
#  1   course_title      602 non-null    object
#  2   price             602 non-null    int64
#  3   Free/Paid         602 non-null    object
#  4   num_subscribers   602 non-null    int64
#  5   num_reviews       602 non-null    int64
#  6   num_lectures      602 non-null    int64
#  7   level             602 non-null    object
#  8   Rating            602 non-null    float64
#  9   content_duration  602 non-null    float64
#  10  published_        602 non-null    object
#  11  Year              602 non-null    int64
#  12  Month             602 non-null    int64
#  13  subject           602 non-null    object
#  14  Revenue           602 non-null    int64
# dtypes: float64(2), int64(8), object(5)
# memory usage: 70.7+ KB

# %%
d1.shape
# Out:
# (602, 15)

# %%
d1.describe()
# Out:
#           course_id       price  num_subscribers  num_reviews  num_lectures
# count  6.020000e+02  602.000000       602.000000   602.000000    602.000000  \
# mean   7.211615e+05   57.890365      1766.026578    61.578073     32.093023
# std    3.471898e+05   57.238456      4926.744878   213.223508     31.363278
# min    1.546700e+04    0.000000         0.000000     0.000000      5.000000
# 25%    4.503640e+05   20.000000        35.000000     3.000000     13.000000
# 50%    7.337660e+05   30.000000       385.500000    10.000000     21.000000
# 75%    1.024108e+06   80.000000      1445.250000    31.000000     39.000000
# max    1.276020e+06  200.000000     53851.000000  2379.000000    225.000000
#
#            Rating  content_duration         Year       Month       Revenue
# count  602.000000        602.000000   602.000000  602.000000  6.020000e+02
# mean     0.730382          3.585465  2015.581395    5.950166  1.278790e+05
# std      0.291171          5.907407     1.185402    3.231631  4.918001e+05
# min      0.010000          0.500000  2012.000000    1.000000  0.000000e+00
# 25%      0.550000          1.000000  2015.000000    3.000000  6.612500e+02
# 50%      0.870000          2.000000  2016.000000    6.000000  9.847500e+03
# 75%      0.950000          4.000000  2017.000000    8.000000  6.164250e+04
# max      0.990000         78.500000  2017.000000   12.000000  7.257600e+06

# %%
sns.histplot(x="price",data=d1,kde=True)
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
d1["Free/Paid"].value_counts().plot(kind="bar",color="purple")

for i,v in enumerate(d1["Free/Paid"].value_counts()):
    plt.text(i,v,str(v))

# %%
a=d1.groupby("Year")["Revenue"].mean()

sns.barplot(x=a.index,y=a.values)
# Out:
# <Axes: xlabel='Year'>

# %%
a=d1.groupby("level")["Revenue"].mean()

sns.barplot(x=a.index,y=a.values)
# Out:
# <Axes: xlabel='level'>

# %% [markdown]
# BUSINESS COURSE

# %%
d2=pd.read_csv("C:\\Users\\thris\\Downloads\\Business Courses.csv")
d2.head(1)
# Out:
#    course_id                                       course_title  price
# 0      49798  Bitcoin or How I Learned to Stop Worrying and ...      0  \
#
#   Free/Paid  num_subscribers  num_reviews  num_lectures       level  Rating
# 0      Free            65576          936            24  All Levels    0.56  \
#
#    content_duration  published_  Year  Month           subject  Revenue
# 0               8.0  20-04-2013  2013      4  Business Finance        0

# %%
d2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1191 entries, 0 to 1190
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   course_id         1191 non-null   int64
#  1   course_title      1191 non-null   object
#  2   price             1191 non-null   int64
#  3   Free/Paid         1191 non-null   object
#  4   num_subscribers   1191 non-null   int64
#  5   num_reviews       1191 non-null   int64
#  6   num_lectures      1191 non-null   int64
#  7   level             1191 non-null   object
#  8   Rating            1191 non-null   float64
#  9   content_duration  1191 non-null   float64
#  10  published_        1191 non-null   object
#  11  Year              1191 non-null   int64
#  12  Month             1191 non-null   int64
#  13  subject           1191 non-null   object
#  14  Revenue           1191 non-null   int64
# dtypes: float64(2), int64(8), object(5)
# memory usage: 139.7+ KB

# %%
sns.histplot(x="price",data=d2)
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
d2["Free/Paid"].value_counts().plot(kind="bar",color="purple")

for i,v in enumerate(d2["Free/Paid"].value_counts()):
    plt.text(i,v,str(v))

# %%
a=d2.groupby("Year")["Revenue"].mean()

sns.barplot(x=a.index,y=a.values)
# Out:
# <Axes: xlabel='Year'>

# %%
a=d2.groupby("level")["Revenue"].mean()

sns.barplot(x=a.index,y=a.values)
# Out:
# <Axes: xlabel='level'>

# %% [markdown]
# WEB DEVELOPMENT COURSE

# %%
d3=pd.read_csv("C:\\Users\\thris\\Downloads\\Web development Courses.csv")
d3.head(1)
# Out:
#    course_id                          course_title  price Free/Paid
# 0      41295  Learn HTML5 Programming From Scratch      0      Free  \
#
#    num_subscribers  num_reviews  num_lectures           level  Rating
# 0           268923         8629            45  Beginner Level    0.82  \
#
#    content_duration  published_  Year  Month          subject  Revenue
# 0              10.5  14-02-2013  2013      2  Web Development        0

# %%
d3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1203 entries, 0 to 1202
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   course_id         1203 non-null   int64
#  1   course_title      1203 non-null   object
#  2   price             1203 non-null   int64
#  3   Free/Paid         1203 non-null   object
#  4   num_subscribers   1203 non-null   int64
#  5   num_reviews       1203 non-null   int64
#  6   num_lectures      1203 non-null   int64
#  7   level             1203 non-null   object
#  8   Rating            1203 non-null   float64
#  9   content_duration  1203 non-null   float64
#  10  published_        1203 non-null   object
#  11  Year              1203 non-null   int64
#  12  Month             1203 non-null   int64
#  13  subject           1203 non-null   object
#  14  Revenue           1203 non-null   int64
# dtypes: float64(2), int64(8), object(5)
# memory usage: 141.1+ KB

# %%
sns.histplot(x="price",data=d3)
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
d3["Free/Paid"].value_counts().plot(kind="bar",color="purple")

for i,v in enumerate(d3["Free/Paid"].value_counts()):
    plt.text(i,v,str(v))

# %%
a=d3.groupby("Year")["Revenue"].mean()

sns.barplot(x=a.index,y=a.values)
# Out:
# <Axes: xlabel='Year'>

# %%
a=d3.groupby("level")["Revenue"].mean()

sns.barplot(x=a.index,y=a.values)
# Out:
# <Axes: xlabel='level'>

# %% [markdown]
# MUSIC COURSE

# %%
d4=pd.read_csv("C:\\Users\\thris\\Downloads\\Music Courses.csv")
d4.head(1)
# Out:
#    course_id                           course_title  price Free/Paid
# 0      19421  Free Beginner Electric Guitar Lessons      0      Free  \
#
#    num_subscribers  num_reviews  num_lectures       level  Rating
# 0           101154         1042            95  All Levels    0.88  \
#
#    content_duration  published_  Year  Month              subject  Revenue
# 0               4.5  15-06-2012  2012      6  Musical Instruments        0

# %%
d4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 680 entries, 0 to 679
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   course_id         680 non-null    int64
#  1   course_title      680 non-null    object
#  2   price             680 non-null    int64
#  3   Free/Paid         680 non-null    object
#  4   num_subscribers   680 non-null    int64
#  5   num_reviews       680 non-null    int64
#  6   num_lectures      680 non-null    int64
#  7   level             680 non-null    object
#  8   Rating            680 non-null    float64
#  9   content_duration  680 non-null    float64
#  10  published_        680 non-null    object
#  11  Year              680 non-null    int64
#  12  Month             680 non-null    int64
#  13  subject           680 non-null    object
#  14  Revenue           680 non-null    int64
# dtypes: float64(2), int64(8), object(5)
# memory usage: 79.8+ KB

# %%
sns.histplot(x="price",data=d4)
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
d4["Free/Paid"].value_counts().plot(kind="bar",color="purple")

for i,v in enumerate(d4["Free/Paid"].value_counts()):
    plt.text(i,v,str(v))

# %%
a=d4.groupby("Year")["Revenue"].mean()

sns.barplot(x=a.index,y=a.values)
# Out:
# <Axes: xlabel='Year'>

# %%
a=d4.groupby("level")["Revenue"].mean()

sns.barplot(x=a.index,y=a.values)
# Out:
# <Axes: xlabel='level'>

# %% [markdown]
# COMBING ALL UDEMY COURSES

# %%
df = pd.concat([d1, d2, d3, d4])

#sample the first rows of the dataframe
print('\n')
print("This combined dataset has {} rows and {} columns".format(df.shape[0], df.shape[1]) )
df.head(2)
# Out:
# This combined dataset has 3676 rows and 15 columns
#    course_id                                       course_title  price
# 0     348116  Photoshop In-Depth: Master all of Photoshop's ...      0  \
# 1      17349  Figure Drawing From Life Using The Reilly Tech...      0
#
#   Free/Paid  num_subscribers  num_reviews  num_lectures           level
# 0      Free            53851         1779            45      All Levels  \
# 1      Free            47811         1041            22  Beginner Level
#
#    Rating  content_duration  published_  Year  Month         subject  Revenue
# 0    0.69               4.5  30-11-2014  2014     11  Graphic Design        0
# 1    0.11               2.5  09-05-2012  2012      5  Graphic Design        0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3676 entries, 0 to 679
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   course_id         3676 non-null   int64
#  1   course_title      3676 non-null   object
#  2   price             3676 non-null   int64
#  3   Free/Paid         3676 non-null   object
#  4   num_subscribers   3676 non-null   int64
#  5   num_reviews       3676 non-null   int64
#  6   num_lectures      3676 non-null   int64
#  7   level             3676 non-null   object
#  8   Rating            3676 non-null   float64
#  9   content_duration  3676 non-null   float64
#  10  published_        3676 non-null   object
#  11  Year              3676 non-null   int64
#  12  Month             3676 non-null   int64
#  13  subject           3676 non-null   object
#  14  Revenue           3676 non-null   int64
# dtypes: float64(2), int64(8), object(5)
# memory usage: 459.5+ KB

# %%
#check for and drop duplicates
df[df.duplicated()]

#drop duplicates in the course id column
df.drop_duplicates(subset=['course_id'],inplace=True)

# %%
#confirm there is no more any null values
df.isnull().sum()
# Out:
# course_id           0
# course_title        0
# price               0
# Free/Paid           0
# num_subscribers     0
# num_reviews         0
# num_lectures        0
# level               0
# Rating              0
# content_duration    0
# published_          0
# Year                0
# Month               0
# subject             0
# Revenue             0
# dtype: int64

# %%
df = df.drop(['num_reviews', 'course_id', 'num_lectures','content_duration'], axis = 1)

# %%
df['num_subscribers'] = df['num_subscribers'].astype('int64')

# %%
df["Free/Paid"].value_counts()
# Out:
# Free/Paid
# Paid    3362
# Free     310
# Name: count, dtype: int64

# %%
counts = df["Free/Paid"].value_counts()

colors = ["#8b33cc", "#48d32c"]
explode = [0.1, 0] 

plt.figure(figsize=(5, 5))
counts.plot(kind="pie", autopct='%1.1f%%', colors=colors, startangle=90, counterclock=False,explode=explode)

plt.title('Distribution of Free/Paid')
plt.ylabel('')

plt.show()

# %%
conditions1 = [
    (df['Rating'] == 0),
    (df['Rating'] > 0) & (df['Rating'] < 0.2),
    (df['Rating'] >= 0.2) & (df['Rating'] < 0.4),
    (df['Rating'] >= 0.4) & (df['Rating'] < 0.6),
    (df['Rating'] >= 0.6) & (df['Rating'] < 0.8),
    (df['Rating'] >= 0.8) 
]
values1 = [0, 1, 2, 3, 4, 5]

df['star_rating'] = np.select(conditions1, values1)

df['star_rating'].value_counts()
# Out:
# star_rating
# 5    1543
# 1     735
# 4     610
# 2     428
# 3     338
# 0      18
# Name: count, dtype: int64

# %%
levels = ({'All Levels':'General', 'Beginner Level':'Beginner', 
           'Intermediate Level':'Intermediate', 'Expert Level':'Expert'})
df['level'] = df['level'].replace(levels)

df['level'].value_counts()
# Out:
# level
# General         1925
# Beginner        1268
# Intermediate     421
# Expert            58
# Name: count, dtype: int64

# %%
level_counts = df['level'].value_counts()

colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728']  

plt.figure(figsize=(10, 6))
bars = level_counts.plot(kind='barh', color=colors)

plt.title('Distribution of Course Levels')
plt.xlabel('Count')
plt.ylabel('Level')

for i,v in enumerate(level_counts):
    plt.text(v,i,str(v))

plt.show()

# %%
df["Year"].value_counts()
# Out:
# Year
# 2016    1204
# 2015    1014
# 2017     713
# 2014     490
# 2013     201
# 2012      45
# 2011       5
# Name: count, dtype: int64

# %%
df["Year"].value_counts().plot(kind="bar")
plt.xlabel("Year")
plt.ylabel("No.of courses")

plt.title("Number of courses yearly")
# Out:
# Text(0.5, 1.0, 'Number of courses yearly')

# %%
df["subject"].value_counts()
# Out:
# subject
# Web Development        1199
# Business Finance       1191
# Musical Instruments     680
# Graphic Design          602
# Name: count, dtype: int64

# %%
subject = df['subject'].value_counts()

print(df['subject'].value_counts())

fig, ax = plt.subplots()

# Pie chart, where the slices will be ordered and plotted counter-clockwise:
wedges, texts, autotexts = ax.pie(
    subject, 
    labels=subject.index, 
    autopct='%1.1f%%', 
    startangle=140, 
    colors=plt.cm.Dark2.colors)

centre_circle = plt.Circle((0,0),0.70,fc='white')
fig.gca().add_artist(centre_circle)

ax.axis('equal')  

plt.title('Distribution of Subject')
plt.tight_layout()

plt.show()
# Out:
# subject
# Web Development        1199
# Business Finance       1191
# Musical Instruments     680
# Graphic Design          602
# Name: count, dtype: int64

# %% [markdown]
# `Web Development` courses were generally more expensive closely followed by `Business Finance` courses.

# %%
#course price versus number of subscribers
fig, ((ax0, ax1), (ax2, ax3 )) = plt.subplots(2,2 ,figsize=(15,10))

values = df.groupby('subject')['price'].mean().round()
ax0.bar(df.groupby('subject')['price'].mean().index, df.groupby('subject')['price'].mean(),color="pink")
ax0.set_title('Average Course Price')
[ax0.text(index, value, str(value)) for index, value in enumerate(values)] #list comprehension to add bar values
    
values = df.groupby('subject')['num_subscribers'].mean().round()    
ax1.bar(df.groupby('subject')['num_subscribers'].sum().index, df.groupby('subject')['num_subscribers'].sum(),color="purple")
ax1.set_title('Number of Subscribers')
[ax1.text(index, value, str(value)) for index, value in enumerate(values)]

values = df.groupby('subject')['course_title'].count()
ax2.bar(df.groupby('subject')['course_title'].count().index, df.groupby('subject')['course_title'].count(),color="green")
ax2.set_title('Number of Published Courses')
[ax2.text(index, value, str(value)) for index, value in enumerate(values)]

values = df.groupby('subject')['Rating'].mean().round(2)
ax3.bar(df.groupby('subject')['Rating'].mean().index, df.groupby('subject')['Rating'].mean(),color="orange")
ax3.set_title('Average Rating')
[ax3.text(index, value, str(value)) for index, value in enumerate(values)]

plt.tight_layout()
plt.show()

# %% [markdown]
# *Web Development* and *Business Finance* have the highest number of paid courses by absolute count; however the percentage free courses is highest in *Web Development*. The expert category has more free courses out of the total published in that level.

# %%
#revenue generation by subject and by course
fig, ((ax0,ax1), (ax2,ax3)) = plt.subplots(2,2 ,figsize=(15,10))

df_free = df.query('price == 0')
(ax0.barh(df_free.groupby('subject')['course_title'].count().index, 
          100*df_free.groupby('subject')['course_title'].count()/
          df.groupby('subject')['course_title'].count()))
ax0.set_title('% Free Courses per Subject')
ax0.set_xlabel('Number of Courses')

df_paid = df.query('price != 0')
ax1.barh(df_paid.groupby('subject')['course_title'].count().index, df_paid.groupby('subject')['course_title'].count())
ax1.set_title('Paid Courses per Subject')
ax1.set_xlabel('Number of Courses')

ax2.barh(df.groupby('level')['price'].mean().index, df.groupby('level')['price'].mean())
ax2.set_title('Average Price for Different Levels of Learning')
ax2.set_xlabel('Price')

df_free = df.query('price == 0')
(ax3.barh(df_free.groupby('level')['course_title'].count().index, 
          100*df_free.groupby('level')['course_title'].count()/
          df.groupby('level')['course_title'].count()))
ax3.set_title('% Free Courses Across Levels')
ax3.set_xlabel('NUmber of Courses')

plt.tight_layout()
plt.show()

# %% [markdown]
# The *The Developer Bootcamp* course, a course on *Web Development*, generates the highest revenue; 90% of the top 20 revenue generating courses are from the Web Development category.

# %%
#revenue generation by subject and by course
fig, ((ax0), (ax1)) = plt.subplots(1, 2 ,figsize=(15,10))

(ax0.barh(df.groupby('subject')['Revenue'].sum().index, sorted(df.groupby('subject')['Revenue'].mean()),color="pink"))
ax0.set_title('Revenue Per Subject')
ax0.set_xlabel('Revenue')


#sort the dataframe by revenue generated and courses and plot top 15
df_rev = df[['course_title', 'Revenue']].sort_values('Revenue', ascending=False).head(15)
(ax1.barh(df_rev.head(15).groupby('course_title')['Revenue'].sum().index, 
          sorted(df_rev.head(15).groupby('course_title')['Revenue'].sum()),color="purple"))
ax1.set_title('Top 10 Revenue Generating Courses')
ax1.set_xlabel('Revenue')

plt.tight_layout()
plt.show()

# %%
#plot of the courses by number of subscribers
df_sub = df.sort_values('num_subscribers', ascending=False).head(20)
df_sub.groupby(['course_title', 'price','subject'])['num_subscribers'].sum().sort_values().plot(kind='barh',color="cyan")
plt.title('20 Most Subscribed Courses')
plt.ylabel('')
plt.xlabel('Number of Subscribers')
plt.rcParams["figure.figsize"] = (10, 12)
plt.show()

# %%
sns.scatterplot(x="price",y="Rating",data=df)
# Out:
# <Axes: xlabel='price', ylabel='Rating'>

# %% [markdown]
# There is no relationship between price and rating

# %%
#course price versus number of subscribers
fig, ((ax0, ax1), (ax2, ax3 )) = plt.subplots(2,2 ,figsize=(15,10))

ax0.bar(d1.price, d1['num_subscribers'], width=2.4)
ax0.set_title('Graphic Design')
ax0.set_ylabel('Number of Subscribers')

ax1.bar(d2.price, d2.num_subscribers, width=2.4)
ax1.set_title('Business Finance')

ax2.bar(d4.price, d4.num_subscribers, width=2.4)
ax2.set_title('Musical Instrument')
ax2.set_xlabel('Course Price')
ax2.set_ylabel('Number of Subscribers')

ax3.bar(d3.price, d3.num_subscribers, width=2.4)
ax3.set_title('Web Development')
ax3.set_xlabel('Course Price')

plt.show()

# %%
fig, ((ax0, ax1), (ax2, ax3)) = plt.subplots(2,2 ,figsize=(15,10))

labels = [0,1,2,3,4,5]

ax0.bar(d2.Year.value_counts().index,d2.Year.value_counts().values)
ax0.set_title('Business Finance')
ax0.set_ylabel('Number of Courses')

ax1.bar(d1.Year.value_counts().index,d1.Year.value_counts().values,color='r')
ax1.set_title('Graphic Design')

ax2.bar(d4.Year.value_counts().index,d4.Year.value_counts().values,color='y')
ax2.set_title('Musical Instruments')
ax2.set_ylabel('Number of Courses')

ax3.bar(d3.Year.value_counts().index,d3.Year.value_counts().values, color='c')
ax3.set_title('Web Development')

fig.tight_layout()
plt.show()

# %%
fig, ((ax0, ax1), (ax2, ax3)) = plt.subplots(2,2 ,figsize=(15,10))

labels = [0,1,2,3,4,5]

ax0.bar(d2.groupby('Year')['Revenue'].sum().index, d2.groupby('Year')['Revenue'].sum())
ax0.set_title('Business Finance')
ax0.set_ylabel('Revenue')

ax1.bar(d1.groupby('Year')['Revenue'].sum().index, d1.groupby('Year')['Revenue'].sum(), color='r')
ax1.set_title('Graphic Design')

ax2.bar(d4.groupby('Year')['Revenue'].sum().index, d4.groupby('Year')['Revenue'].sum(),color='y')
ax2.set_title('Musical Instruments')
ax2.set_ylabel('Revenue')

ax3.bar(d3.groupby('Year')['Revenue'].sum().index, d3.groupby('Year')['Revenue'].sum(), color='c')
ax3.set_title('Web Development')

fig.tight_layout()
plt.show()

# %% [markdown]
# ### Insights
# - `Web Development` and `Graphics Designs` have the highest and lowest number of published courses respectively.
# - Subscribers are more interested in `Web Development` courses and least in `Musical Instruments` courses.
# - `Graphics Design` courses followed by `Business Finance` received the best ratings.
# - `Web Development` courses are more expensive, attractive more subscribers; hence generate the highest revenue.
# - The % of the courses that are free are more in expert level.
# - The courses received high ratings across board.
# - The year 2016 has highest number of courses published across the different subjects.
# - For revenue generation, 2014 was the big year for `Musical Instruments`, 2015 for `Business Finance` and `Web Development` while `Graphics Design` made the most revenue in 2016.
